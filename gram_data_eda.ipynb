# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('merged_gram_reservoir.csv')

print(" Shape of the dataset:")
print(df.shape)

print("\n Columns and Data Types:")
print(df.dtypes)

print("\n First 5 Rows:")
print(df.head())

print("\n Missing Values:")
print(df.isnull().sum())

print("\n Unique Values in Each Column:")
print(df.nunique())

print("\n Column-wise Null Percentage:")
print((df.isnull().mean() * 100).round(2))

print("\n Duplicate Rows:")
print(df.duplicated().sum())
# Out:
#  Shape of the dataset:
# (107753, 12)
#
#  Columns and Data Types:
# state_name                    object
# crop_name                     object
# apy_item_interval_start        int64
# temperature_recorded_date     object
# state_temperature_max_val    float64
# state_temperature_min_val    float64
# state_rainfall_val           float64
# yield                        float64
# FRL                          float64
# Live Cap FRL                 float64
# Level                        float64
# Current Live Storage         float64
# dtype: object
#
#  First 5 Rows:
#        state_name crop_name  apy_item_interval_start  \
# 0  Andhra Pradesh      gram                     2000
# 1  Andhra Pradesh      gram                     2000
# 2  Andhra Pradesh      gram                     2000
# 3  Andhra Pradesh      gram                     2000
# 4  Andhra Pradesh      gram                     2000
#
#   temperature_recorded_date  state_temperature_max_val  \
# 0                2000-01-01                      30.38
# 1                2000-01-02                      30.04
# 2                2000-01-03                      29.92
# 3                2000-01-04                      29.98
# 4                2000-01-05                      29.77
#
#    state_temperature_min_val  state_rainfall_val    yield         FRL  \
# 0                      14.47                 0.0  1.22615  152.296667
# 1                      13.96                 0.0  1.22615  152.296667
# 2                      12.98                 0.0  1.22615  152.296667
# 3                      12.23                 0.0  1.22615  152.296667
# 4                      13.24                 0.0  1.22615  152.296667
#
#    Live Cap FRL   Level  Current Live Storage
# 0      2.838333  266.30                 6.390
# 1      2.838333  266.18                 6.330
# 2      2.838333  266.09                 6.286
# 3      2.838333  266.03                 6.257
# 4      2.838333  265.97                 6.228
#
#  Missing Values:
# state_name                     0
# crop_name                      0
# apy_item_interval_start        0
# temperature_recorded_date      0
# state_temperature_max_val      0
# state_temperature_min_val      0
# state_rainfall_val             0
# yield                          0
# FRL                            0
# Live Cap FRL                   0
# Level                        400
# Current Live Storage         397
# dtype: int64
#
#  Unique Values in Each Column:
# state_name                      14
# crop_name                        1
# apy_item_interval_start         23
# temperature_recorded_date     8401
# state_temperature_max_val     3092
# state_temperature_min_val     2690
# state_rainfall_val            3790
# yield                          294
# FRL                             17
# Live Cap FRL                    17
# Level                        83324
# Current Live Storage         73155
# dtype: int64
#
#  Column-wise Null Percentage:
# state_name                   0.00
# crop_name                    0.00
# apy_item_interval_start      0.00
# temperature_recorded_date    0.00
# state_temperature_max_val    0.00
# state_temperature_min_val    0.00
# state_rainfall_val           0.00
# yield                        0.00
# FRL                          0.00
# Live Cap FRL                 0.00
# Level                        0.37
# Current Live Storage         0.37
# dtype: float64
#
#  Duplicate Rows:
# 0
